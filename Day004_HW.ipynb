# %%
#比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
import json
import requests
r=requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
print(type(r.text))
print(type(json.loads(r.text)))
# Out:
# <class 'str'>
# <class 'dict'>

# %%
import requests
r=requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
r.text
# Out:
# '{"@odata.context": "http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel",\n"@odata.count": 100,\n"value": [{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "2560H020","WaterLevel": 0.3},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1650H008","WaterLevel": 0.41},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1630H036","WaterLevel": 65.85},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1730H075","WaterLevel": -999998},{"RecordTime": "Dec 8, 2019 1:50:00 PM","StationIdentifier": "1630H031","WaterLevel": 0.37},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1730H061","WaterLevel": 266.24},{"RecordTime": "Dec 8, 2019 1:50:00 PM","StationIdentifier": "1630H027","WaterLevel": 26.19},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1850H004","WaterLevel": 72.08},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1730H057","WaterLevel": 43.45},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1630H023","WaterLevel": 0.04},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "2420H036","WaterLevel": 164.37},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1550H012","WaterLevel": 0.24},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1650H013","WaterLevel": 5.66},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1430H051","WaterLevel": 95.72},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "2200H007","WaterLevel": 156.15},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1540H037","WaterLevel": 31.92},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1540H029","WaterLevel": 12.81},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "2420H018","WaterLevel": 156.28},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1540H032","WaterLevel": 20.23},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1730H077","WaterLevel": 740.51},{"RecordTime": "Dec 8, 2019 2:10:00 PM","StationIdentifier": "1510H083","WaterLevel": 116.66},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "2370H025","WaterLevel": 261.62},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1730H072","WaterLevel": 248.9},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1350H031","WaterLevel": -0.36},{"RecordTime": "Dec 8, 2019 2:10:00 PM","StationIdentifier": "1510H071","WaterLevel": 20.69},{"RecordTime": "Dec 8, 2019 1:50:00 PM","StationIdentifier": "1630H033","WaterLevel": 0.05},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1730H068","WaterLevel": 10.14},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1350H028","WaterLevel": 232.68},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1340H014","WaterLevel": 0.32},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "2420H043","WaterLevel": 79.44},{"RecordTime": "Dec 8, 2019 1:50:00 PM","StationIdentifier": "1630H030","WaterLevel": 1.56},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1430H047","WaterLevel": 72.36},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1730H043","WaterLevel": 23.08},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "2560H024","WaterLevel": 202.84},{"RecordTime": "Dec 8, 2019 1:20:00 PM","StationIdentifier": "1630H034","WaterLevel": 278.46},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1350H024","WaterLevel": 259.7},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1340H011","WaterLevel": 7.38},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "2420H024","WaterLevel": 4.81},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1630H025","WaterLevel": 1.45},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1420H058","WaterLevel": 440.48},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "1550H016","WaterLevel": 12.32},{"RecordTime": "Dec 8, 2019 2:20:00 PM","StationIdentifier": "2560H019","Wa ...

# %%
import json
json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2560H020',
#    'WaterLevel': 0.3},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1650H008',
#    'WaterLevel': 0.41},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H036',
#    'WaterLevel': 65.85},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1730H075',
#    'WaterLevel': -999998},
#   {'RecordTime': 'Dec 8, 2019 1:50:00 PM',
#    'StationIdentifier': '1630H031',
#    'WaterLevel': 0.37},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1730H061',
#    'WaterLevel': 266.24},
#   {'RecordTime': 'Dec 8, 2019 1:50:00 PM',
#    'StationIdentifier': '1630H027',
#    'WaterLevel': 26.19},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1850H004',
#    'WaterLevel': 72.08},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1730H057',
#    'WaterLevel': 43.45},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H023',
#    'WaterLevel': 0.04},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2420H036',
#    'WaterLevel': 164.37},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1550H012',
#    'WaterLevel': 0.24},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1650H013',
#    'WaterLevel': 5.66},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1430H051',
#    'WaterLevel': 95.72},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2200H007',
#    'WaterLevel': 156.15},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1540H037',
#    'WaterLevel': 31.92},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1540H029',
#    'WaterLevel': 12.81},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2420H018',
#    'WaterLevel': 156.28},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1540H032',
#    'WaterLevel': 20.23},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1730H077',
#    'WaterLevel': 740.51},
#   {'RecordTime': 'Dec 8, 2019 2:10:00 PM',
#    'StationIdentifier': '1510H083',
#    'WaterLevel': 116.66},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2370H025',
#    'WaterLevel': 261.62},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1730H072',
#    'WaterLevel': 248.9},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1350H031',
#    'WaterLevel': -0.36},
#   {'RecordTime': 'Dec 8, 2019 2:10:00 PM',
#    'StationIdentifier': '1510H071',
#    'WaterLevel': 20.69},
#   {'RecordTime': 'Dec 8, 2019 1:50:00 PM',
#    'StationIdentifier': '1630H033',
#    'WaterLevel': 0.05},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1730H068',
#    'WaterLevel': 10.14},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1350H028',
#    'WaterLevel': 232.68},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1340H014',
#    'WaterLevel': 0.32},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2420H043',
#    'WaterLevel': 79.44},
#   {'RecordTime': 'Dec 8, 2019 1:50:00 PM',
#    'StationIdentifier': '1630H030',
#    'WaterLevel': 1.56},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1430H047',
#    'WaterLevel': 72.36},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1730H043',
#    'WaterLevel': 23.08},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2560H024',
#    'WaterLevel': 202.84},
#   {'RecordTime': 'Dec 8, 2019 1:20:00 PM',
#    'StationIdentifier': '1630H034',
#    'WaterLevel': 278.46},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1350H024',
#    'WaterLevel': 259.7},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1340H011',
#    'WaterLevel': 7.38},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2420H024',
#    'WaterLevel': 4.81},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H025',
#    'WaterLevel': 1.45},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1420H058',
#    'WaterLevel': 440.48},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1550H016',
#    'WaterLevel': 12.32},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2560H019',
#    'WaterLevel': 4.51},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1430H056',
#    'WaterLevel': 79.82},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1350H020',
#    'WaterLevel': 220.8},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1320H001',
#    'WaterLevel': 2.65},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2370H004',
#    'WaterLevel': 192.68},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1580H022',
#    'WaterLevel': 0.02},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1420H055',
#    'WaterLevel': 318.95},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1740H010',
#    'WaterLevel': 47.04},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1540H035',
#    'WaterLevel': 86.81},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1590H013',
#    'WaterLevel': 20.79},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1430H045',
#    'WaterLevel': 91.64},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1350H016',
#    'WaterLevel': 98.05},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2200H022',
#    'WaterLevel': 161.04},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1300H023',
#    'WaterLevel': 52.32},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2370H018',
#    'WaterLevel': 124.09},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1430H037',
#    'WaterLevel': 380.49},
#   {'RecordTime': 'Dec 8, 2019 2:10:00 PM',
#    'StationIdentifier': '1140H110',
#    'WaterLevel': 42.68},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1740H002',
#    'WaterLevel': 4.42},
#   {'RecordTime': 'Dec 8, 2019 2:30:00 PM',
#    'StationIdentifier': '1730H066',
#    'WaterLevel': 138.58},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1540H030',
#    'WaterLevel': 27.17},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1430H054',
#    'WaterLevel': 48.34},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2560H006',
#    'WaterLevel': 3.52},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1430H040',
#    'WaterLevel': 19.47},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1340H015',
#    'WaterLevel': 50.08},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H005',
#    'WaterLevel': 39.76},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1300H020',
#    'WaterLevel': 251.5},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2200H011',
#    'WaterLevel': 25.85},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1430H029',
#    'WaterLevel': 50.59},
#   {'RecordTime': 'Dec 8, 2019 2:10:00 PM',
#    'StationIdentifier': '1140H066',
#    'WaterLevel': 2.49},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1730H071',
#    'WaterLevel': 35.29},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1670H003',
#    'WaterLevel': 0.3},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1540H009',
#    'WaterLevel': -0.04},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2420H046',
#    'WaterLevel': 35.99},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1300H022',
#    'WaterLevel': -1.33},
#   {'RecordTime': 'Dec 8, 2019 2:25:00 PM',
#    'StationIdentifier': '1140H107',
#    'WaterLevel': 3.41},
#   {'RecordTime': 'Dec 8, 2019 2:10:00 PM',
#    'StationIdentifier': '2200H029',
#    'WaterLevel': 145.15},
#   {'RecordTime': 'Dec 8, 2019 2:10:00 PM',
#    'StationIdentifier': '1420H053',
#    'WaterLevel': 471.59},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1300H019',
#    'WaterLevel': -999998},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H020',
#    'WaterLevel': 35.3},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1420H057',
#    'WaterLevel': 639.41},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2560H023',
#    'WaterLevel': 13.28},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': 25.73},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1730H062',
#    'WaterLevel': 41.78},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1660H011',
#    'WaterLevel': 1.48},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1510H088',
#    'WaterLevel': 141.11},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2200H028',
#    'WaterLevel': 278.1},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1660H013',
#    'WaterLevel': 0.87},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1290H007',
#    'WaterLevel': 12.8},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1140H101',
#    'WaterLevel': 182.12},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1740H009',
#    'WaterLevel': 32.38},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1280H001',
#    'WaterLevel': 71.48},
#   {'RecordTime': 'Dec 8, 2019 2:10:00 PM',
#    'StationIdentifier': '1140H076',
#    'WaterLevel': 135.45},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1590H016',
#    'WaterLevel': 11.32},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1400H015',
#    'WaterLevel': 624.95},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '2560H017',
#    'WaterLevel': 366.4},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1550H011',
#    'WaterLevel': 0.06},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1680H005',
#    'WaterLevel': 0.17},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1660H009',
#    'WaterLevel': 4.89},
#   {'RecordTime': 'Dec 8, 2019 2:20:00 PM',
#    'StationIdentifier': '1350H018',
#    'WaterLevel': 282.06}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
