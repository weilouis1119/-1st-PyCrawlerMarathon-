# %% [markdown]
# # Wikipedia爬蟲練習
# ## 範例：練習是從Wikipedia中爬取文章。先定義一個搜尋的關鍵字，擷取該關鍵字詞的文章。

# %%
import requests
import re
from bs4 import BeautifulSoup
import os

# %% [markdown]
# ### 先定義一個我們想搜尋的字詞，並將它轉換成UTF-8編碼後的URL

# %%
input_keyword = "板橋林家"  # 這裡可以自己定義有興趣的關鍵字

utf8_url = repr(input_keyword.encode('UTF-8')).upper()  # 編碼成UTF-8並轉成大寫字元
utf8_url = utf8_url.replace("\\X", "%")                 # 用 '%' 取代 '\X' 
print("%s: %s" % (input_keyword, utf8_url[2:-1:1]))     # 擷取中間的編碼結果

# 組成Wiki關鍵字搜尋的網址格式
root_keyword_link = '/wiki/' + utf8_url[2:-1:1]
print(root_keyword_link)
# Out:
# 板橋林家: %E6%9D%BF%E6%A9%8B%E6%9E%97%E5%AE%B6
# /wiki/%E6%9D%BF%E6%A9%8B%E6%9E%97%E5%AE%B6

# %% [markdown]
# ### 範例1：送出關鍵字請求後，爬取該關鍵字的文章內容

# %%
# 模擬封包的標頭
headers = {
    'authority': 'zh.wikipedia.org',
    'method': 'GET',
    'path': '/wiki/' + root_keyword_link,
    'scheme': 'https',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
    'dnt': '1',
    #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
    'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}    

url = 'https://zh.wikipedia.org' + root_keyword_link  # 組合關鍵字查詢URL
resp = requests.get(url, headers=headers)
resp.encoding = 'utf-8'

html = BeautifulSoup(resp.text, "lxml")
content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')

#
# 解析回傳資料，並萃取文章內容
#
for paragraph in content:
    print(paragraph.get_text())
# Out:
# 林本源家族，或稱板橋林家，為台灣五大家族之一，與霧峰林家並稱，臺灣人稱「一天下，兩林家」[1]。林本源家族清朝時發跡於板橋。「林本源」並不是人名，而是板橋林家的「商號」。
#
# 2008年6月，富比士公布出身板橋林家、任華南金控董事長的林明成身價淨值12億美元，居是年台灣第二十[2]。
#
# 林家是福建漳州府龍溪縣白石堡吉上社（今日漳州市龍海市角美鎮）人，開臺祖林應寅於清朝乾隆49年（1784年）攜長子林平侯渡海來臺灣於臺北新莊落腳。
#
# 林平侯後來經營米業、鹽業，在林爽文事件中物價暴漲因而糶米致富，並且捐官入仕，曾任新竹縣丞、後升廣西柳州知府，後辭官專心營利，又因新莊泉州人聲勢太盛，舉家遷居桃園大溪。
#
# 平侯遺囑死後取「飲水本思源」之義將家產分為「飲記」、「水記」、「本記」、「思記」、「源記」五記，分別給林國棟、林國仁、林國華、林國英與林國芳五個兒子及其後代（長子林國棟早逝，「飲」商記由本記林國華之子林維讓兼祧承擔）。[3]
# 林爾嘉長子林景仁娶南洋棉蘭（印尼第3大城，位於蘇門達臘，與鄰馬來西亞隔馬六甲海峽相望）富商張鴻南（又稱張耀軒）的千金張福英，後代居於新加坡。
#
# 林家與連家為世交。林熊徵設「薇風會」，連雅堂之子連震東為其成員。林熊徵之妻盛關頤的「秘書」林伯奏，娶連震東胞姊連夏甸（兩人長女為作家林文月，次女婿則是前任臺北市長黃大洲）。
#
# 板橋林家總執事（管家）林登雲為桃園大溪「梅鶴山莊」創立人，其後人林本誠是新北市長朱立倫的外祖父。另朱立倫的大舅林熺達曾擔任大溪鎮長。
#
# 臺北知名私立學校「薇閣中小學」董事長李傳洪是林家總管李土的後人。李傳洪之子李承宗娶許丙的曾孫女許元齡。

# %% [markdown]
# ### 範例2：從爬取的文章內容中，擷取出有外部連結的關鍵字。這些關鍵字在文章中是以藍色字體顯示，會連到外部的網頁，並解釋其內容。

# %%
for ext_link in content:
    a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
    if len(a_tag) > 0:
        for link_string in a_tag:
            a_link = link_string["href"]       # 外部連結的網址
            a_keyword = link_string.get_text()  # 外部連結的中文名稱
            print("外部連結: [%s] %s" % (a_keyword, a_link))
# Out:
# 外部連結: [台灣五大家族] /wiki/%E5%8F%B0%E7%81%A3%E4%BA%94%E5%A4%A7%E5%AE%B6%E6%97%8F
# 外部連結: [霧峰林家] /wiki/%E9%9C%A7%E5%B3%B0%E6%9E%97%E5%AE%B6
# 外部連結: [臺灣人] /wiki/%E8%87%BA%E7%81%A3%E4%BA%BA
# 外部連結: [板橋] /wiki/%E6%9D%BF%E6%A9%8B%E5%8D%80_(%E5%8F%B0%E7%81%A3)
# 外部連結: [富比士] /wiki/%E5%AF%8C%E6%AF%94%E5%A3%AB
# 外部連結: [華南金控] /wiki/%E8%8F%AF%E5%8D%97%E9%87%91%E6%8E%A7
# 外部連結: [林明成] /wiki/%E6%9E%97%E6%98%8E%E6%88%90
# 外部連結: [美元] /wiki/%E7%BE%8E%E5%85%83
# 外部連結: [福建] /wiki/%E7%A6%8F%E5%BB%BA
# 外部連結: [漳州府] /wiki/%E6%BC%B3%E5%B7%9E%E5%BA%9C
# 外部連結: [龍溪縣] /wiki/%E9%BE%99%E6%BA%AA%E5%8E%BF
# 外部連結: [漳州市] /wiki/%E6%BC%B3%E5%B7%9E%E5%B8%82
# 外部連結: [龍海市] /wiki/%E9%BE%8D%E6%B5%B7%E5%B8%82
# 外部連結: [角美鎮] /wiki/%E8%A7%92%E7%BE%8E%E9%95%87
# 外部連結: [清朝] /wiki/%E6%B8%85%E6%9C%9D
# 外部連結: [乾隆] /wiki/%E4%B9%BE%E9%9A%86
# 外部連結: [林平侯] /wiki/%E6%9E%97%E5%B9%B3%E4%BE%AF
# 外部連結: [臺北] /wiki/%E6%96%B0%E5%8C%97%E5%B8%82
# 外部連結: [新莊] /wiki/%E6%96%B0%E8%8E%8A%E5%8D%80
# 外部連結: [林平侯] /wiki/%E6%9E%97%E5%B9%B3%E4%BE%AF
# 外部連結: [管家] /wiki/%E7%AE%A1%E5%AE%B6
# 外部連結: [林登雲] /wiki/%E6%9E%97%E7%99%BB%E9%9B%B2
# 外部連結: [大溪] /wiki/%E5%A4%A7%E6%BA%AA
# 外部連結: [新北市長] /wiki/%E6%96%B0%E5%8C%97%E5%B8%82%E9%95%B7
# 外部連結: [朱立倫] /wiki/%E6%9C%B1%E7%AB%8B%E5%80%AB
# 外部連結: [外祖父] /wiki/%E5%A4%96%E7%A5%96%E7%88%B6
# 外部連結: [大溪] /wiki/%E5%A4%A7%E6%BA%AA
# 外部連結: [董事長] /wiki/%E8%91%A3%E4%BA%8B%E9%95%B7
# 外部連結: [李承宗] /wiki/%E6%9D%8E%E6%89%BF%E5%AE%97
# 外部連結: [許丙] /wiki/%E8%A8%B1%E4%B8%99

# %% [markdown]
# ## 作業：接下來定義一個爬蟲函數，這個函數的主要工作為：
# ### (1) 爬取當前關鍵字的解釋，並存入檔案(因為文章內容太多會佔滿整個頁面，所以存程檔案，方便後續檢視)
# ### (2) 萃取出當前關鍵字所引用的外部連結，當作新的查詢關鍵字
# ### (3) 把第(2)擷取到的關鍵字當作新的關鍵字，回到第(1)步，爬取新的關鍵字解釋。

# %%
def WikiArticle(root_keyword_link, input_keyword, recursive):
    
    if (recursive <= max_recursive_depth):
        print("遞迴層[%d] - %s (%s)" % (recursive, root_keyword_link, input_keyword))
        
        # 模擬封包的標頭
        headers = {
            'authority': 'zh.wikipedia.org',
            'method': 'GET',
            'path': '/wiki/' + root_keyword_link,
            'scheme': 'https',
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
            'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
            'dnt': '1',
            #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
            'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
        }    

        url = 'https://zh.wikipedia.org' + root_keyword_link  # 組合關鍵字查詢URL
        resp = requests.get(url, headers=headers)
        resp.encoding = 'utf-8'

        html = BeautifulSoup(resp.text, "lxml")
        content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')
        
        #
        # Part 1: 請參考範例1，爬取當前關鍵字的文章內容。
        #         因為內容太多，我們把它寫入檔案，並以關鍵字作為檔案名稱，以便稍後查閱內容。
        #         請先建立一個名為"WikiArticle"的資料夾，爬取到的文章內容會放在這個資料夾底下。
        #
        titlename=html.find(name='h1',attrs={'id':'firstHeading'}).text
        if '/' in titlename:
            titlename.replace('/','')
        
        if  not os.path.exists('.WikiArticle'):
            os.mkdir('.WikiArticle')
        
        with open(r'{0}/{1}.txt'.format('.WikiArticle','titlename'),'w',encoding='utf-8') as f:
            
            for paragraph in content:
                f.write(paragraph.get_text()+'\n')
        
        
        
        #
        # Part 2: 請參考範例2，萃取出本篇文章中所延伸引用的外部連結，並儲存在external_link_dict
        #

        external_link_dict = dict({})
        for ext_link in content: 
            a_tag=ext_link.find_all('a',href=re.compile("^(/wiki/)((?!;)\S)*$"))
            if len(a_tag)>0:
                for link_string in a_tag:
                    a_link=link_string['href']
                    a_key_word=link_string.get_text()
                    external_link_dict[a_link]=[a_key_word]
                        #print('外部連結[%s]%s'% (a_link,a_key_word))

                    
        #
        # Part 3: 將Part 2所收集的外部連結，當作新的關鍵字，繼續迭代深入爬蟲
        #
        if (len(external_link_dict) > 0):
            
            recursive = recursive + 1  # 遞迴深度加1
            
            for k, v in external_link_dict.items():
                WikiArticle(k,v, recursive)  # 再次呼叫同樣的函數，執行同樣的流程

# %% [markdown]
# ### 執行前個步驟定義好的爬蟲主程式

# %%
# 定義爬取的遞迴深度。深度不要訂太深，否則會爬很久。
max_recursive_depth = 1


WikiArticle(root_keyword_link, input_keyword, 0)
# Out:
# 遞迴層[0] - /wiki/%E6%9D%BF%E6%A9%8B%E6%9E%97%E5%AE%B6 (板橋林家)
# 遞迴層[1] - /wiki/%E5%8F%B0%E7%81%A3%E4%BA%94%E5%A4%A7%E5%AE%B6%E6%97%8F (['台灣五大家族'])
# 遞迴層[1] - /wiki/%E9%9C%A7%E5%B3%B0%E6%9E%97%E5%AE%B6 (['霧峰林家'])
# 遞迴層[1] - /wiki/%E8%87%BA%E7%81%A3%E4%BA%BA (['臺灣人'])
# 遞迴層[1] - /wiki/%E6%9D%BF%E6%A9%8B%E5%8D%80_(%E5%8F%B0%E7%81%A3) (['板橋'])
# 遞迴層[1] - /wiki/%E5%AF%8C%E6%AF%94%E5%A3%AB (['富比士'])
# 遞迴層[1] - /wiki/%E8%8F%AF%E5%8D%97%E9%87%91%E6%8E%A7 (['華南金控'])
# 遞迴層[1] - /wiki/%E6%9E%97%E6%98%8E%E6%88%90 (['林明成'])
# 遞迴層[1] - /wiki/%E7%BE%8E%E5%85%83 (['美元'])
# 遞迴層[1] - /wiki/%E7%A6%8F%E5%BB%BA (['福建'])
# 遞迴層[1] - /wiki/%E6%BC%B3%E5%B7%9E%E5%BA%9C (['漳州府'])
# 遞迴層[1] - /wiki/%E9%BE%99%E6%BA%AA%E5%8E%BF (['龍溪縣'])
# 遞迴層[1] - /wiki/%E6%BC%B3%E5%B7%9E%E5%B8%82 (['漳州市'])
# 遞迴層[1] - /wiki/%E9%BE%8D%E6%B5%B7%E5%B8%82 (['龍海市'])
# 遞迴層[1] - /wiki/%E8%A7%92%E7%BE%8E%E9%95%87 (['角美鎮'])
# 遞迴層[1] - /wiki/%E6%B8%85%E6%9C%9D (['清朝'])
# 遞迴層[1] - /wiki/%E4%B9%BE%E9%9A%86 (['乾隆'])
# 遞迴層[1] - /wiki/%E6%9E%97%E5%B9%B3%E4%BE%AF (['林平侯'])
# 遞迴層[1] - /wiki/%E6%96%B0%E5%8C%97%E5%B8%82 (['臺北'])
# 遞迴層[1] - /wiki/%E6%96%B0%E8%8E%8A%E5%8D%80 (['新莊'])
# 遞迴層[1] - /wiki/%E7%B1%B3 (['米'])
# 遞迴層[1] - /wiki/%E9%A3%9F%E7%9B%90 (['鹽'])
# 遞迴層[1] - /wiki/%E6%9E%97%E7%88%BD%E6%96%87%E4%BA%8B%E4%BB%B6 (['林爽文事件'])
# 遞迴層[1] - /wiki/%E6%8D%90%E5%AE%98 (['捐官'])
# 遞迴層[1] - /wiki/%E6%96%B0%E7%AB%B9%E7%B8%A3_(%E6%B8%85%E6%9C%9D) (['新竹縣'])
# 遞迴層[1] - /wiki/%E5%BB%A3%E8%A5%BF (['廣西'])
# 遞迴層[1] - /wiki/%E6%9F%B3%E5%B7%9E (['柳州'])
# 遞迴層[1] - /wiki/%E7%9F%A5%E5%BA%9C (['知府'])
# 遞迴層[1] - /wiki/%E6%B3%89%E5%B7%9E (['泉州'])
# 遞迴層[1] - /wiki/%E6%A1%83%E5%9C%92%E5%B8%82 (['桃園'])
# 遞迴層[1] - /wiki/%E5%A4%A7%E6%BA%AA%E5%8D%80 (['大溪'])
# 遞迴層[1] - /wiki/%E9%81%BA%E5%9B%91 (['遺囑'])
# 遞迴層[1] - /wiki/%E6%9E%97%E5%9C%8B%E8%8F%AF (['林國華'])
# 遞迴層[1] - /wiki/%E6%9E%97%E5%9C%8B%E8%8A%B3 (['林國芳'])
# 遞迴層[1] - /wiki/%E6%9D%BF%E6%A9%8B%E6%9E%97%E5%AE%B6%E8%8A%B1%E5%9C%92 (['板橋林家花園'])
# 遞迴層[1] - /wiki/%E5%8F%A4%E8%B9%9F (['古蹟'])
# 遞迴層[1] - /wiki/%E6%97%8F%E9%95%B7 (['族長'])
# 遞迴層[1] - /wiki/%E6%9E%97%E7%B6%AD%E6%BA%90 (['林維源'])
# 遞迴層[1] - /wiki/%E6%9E%97%E5%AE%B6%E8%8A%B1%E5%9C%92 (['林家花園'])
# 遞迴層[1] - /wiki/%E5%98%89%E6%85%B6 (['嘉慶'])
# 遞迴層[1] - /wiki/%E8%87%BA%E7%81%A3 (['臺灣'])
# 遞迴層[1] - /wiki/%E5%9C%B0%E4%B8%BB (['地主'])
# 遞迴層[1] - /wiki/%E5%8F%B0%E7%94%B2 (['甲'])
# 遞迴層[1] - /wiki/%E5%9D%AA (['坪'])
# 遞迴層[1] - /wiki/%E5%92%B8%E8%B1%90 (['咸豐'])
# 遞迴層[1] - /wiki/%E5%90%8C%E6%B2%BB (['同治'])
# 遞迴層[1] - /wiki/%E6%97%A5%E6%9C%AC%E5%B8%9D%E5%9C%8B (['日本帝國'])
# 遞迴層[1] - /wiki/%E5%AE%AE%E5%8F%A4%E5%B3%B6%E6%B0%91%E5%8F%B0%E7%81%A3%E9%81%87%E5%AE%B3%E4%BA%8B%E4%BB%B6 (['琉球漂民為土著所殺'])
# 遞迴層[1] - /wiki/%E7%89%A1%E4%B8%B9%E7%A4%BE%E4%BA%8B%E4%BB%B6 (['牡丹社事件'])
# 遞迴層[1] - /wiki/%E6%B8%85%E5%BB%B7 (['清廷'])
# 遞迴層[1] - /wiki/%E5%A4%AA%E5%B9%B3%E5%A4%A9%E5%9C%8B (['太平天國'])
# 遞迴層[1] - /wiki/%E6%B2%88%E8%91%86%E7%A6%8E (['沈葆禎'])
# 遞迴層[1] - /wiki/%E6%AC%BD%E5%B7%AE%E5%A4%A7%E8%87%A3 (['欽差大臣'])
# 遞迴層[1] - /wiki/%E9%8A%80 (['銀'])
# 遞迴層[1] - /wiki/%E5%8F%B0%E7%81%A3%E6%B5%B7%E5%B3%BD (['臺海'])
# 遞迴層[1] - /wiki/%E5%BE%8C%E5%B1%B1 (['後山'])
# 遞迴層[1] - /wiki/%E5%85%89%E7%B7%92 (['光緒'])
# 遞迴層[1] - /wiki/%E4%B8%AD%E6%B3%95%E6%88%B0%E7%88%AD (['中法戰爭'])
# 遞迴層[1] - /wiki/%E5%8A%89%E9%8A%98%E5%82%B3 (['劉銘傳'])
# 遞迴層[1] - /wiki/%E5%B7%A1%E6%92%AB (['巡撫'])
# 遞迴層[1] - /wiki/%E5%85%A9 (['兩'])
# 遞迴層[1] - /wiki/%E9%8A%80%E5%9C%93 (['銀圓'])
# 遞迴層[1] - /wiki/%E7%BA%A2%E9%A1%B6%E5%95%86%E4%BA%BA (['紅頂商人'])
# 遞迴層[1] - /wiki/%E7%87%95%E4%BA%AC (['燕京'])
# 遞迴層[1] - /wiki/%E6%9D%8E%E9%B4%BB%E7%AB%A0 (['李鴻章'])
# 遞迴層[1] - /wiki/%E7%9B%9B%E5%AE%A3%E6%87%B7 (['盛宣懷'])
# 遞迴層[1] - /wiki/%E5%A4%AA%E5%83%95%E5%AF%BA (['太僕寺'])
# 遞迴層[1] - /wiki/%E6%85%88%E7%A6%A7%E5%A4%AA%E5%90%8E (['慈禧'])
# 遞迴層[1] - /wiki/%E5%85%AC%E5%8D%BF (['公卿'])
# 遞迴層[1] - /wiki/%E8%98%87%E5%B7%9E (['蘇州'])
# 遞迴層[1] - /wiki/%E7%95%99%E5%9C%92 (['留園'])
# 遞迴層[1] - /wiki/%E4%B8%AD%E5%9B%BD%E5%86%85%E5%9C%B0 (['唐山'])
# 遞迴層[1] - /wiki/%E7%94%B2%E5%8D%88%E6%88%B0%E7%88%AD (['甲午戰爭'])
# 遞迴層[1] - /wiki/%E5%BB%88%E9%96%80 (['廈門'])
# 遞迴層[1] - /wiki/%E9%BC%93%E6%B5%AA%E5%B6%BC (['鼓浪嶼'])
# 遞迴層[1] - /wiki/%E5%8F%B0%E7%81%A3%E6%97%A5%E6%B2%BB%E6%99%82%E4%BB%A3 (['日治時代'])
# 遞迴層[1] - /wiki/%E8%87%BA%E7%81%A3%E7%B8%BD%E7%9D%A3%E5%BA%9C (['臺灣總督府'])
# 遞迴層[1] - /wiki/%E8%89%8B%E8%88%BA (['艋舺'])
# 遞迴層[1] - /wiki/%E6%B4%AA%E5%90%88%E7%9B%8A (['洪合益'])
# 遞迴層[1] - /wiki/%E5%9C%93 (['圓'])
# 遞迴層[1] - /wiki/%E5%A4%A7%E7%A8%BB%E5%9F%95 (['大稻埕'])
# 遞迴層[1] - /wiki/%E6%9D%8E%E6%98%A5%E7%94%9F (['李春生'])
# 遞迴層[1] - /wiki/%E6%9D%BF%E6%A9%8B%E6%9E%97%E5%AE%B6 (['板橋林家'])
# 遞迴層[1] - /wiki/%E6%97%A5%E5%9C%93 (['日圓'])
# 遞迴層[1] - /wiki/%E6%B3%95%E5%9C%8B (['法國'])
# 遞迴層[1] - /wiki/%E6%B3%89%E5%AE%89 (['泉安'])
# 遞迴層[1] - /wiki/%E8%88%89%E4%BA%BA (['舉人'])
# 遞迴層[1] - /wiki/%E9%96%A9%E5%8D%97 (['閩南'])
# 遞迴層[1] - /wiki/%E9%93%B6%E4%B8%A4 (['白銀'])
# 遞迴層[1] - /wiki/%E5%8C%AF%E7%8E%87 (['匯率'])
# 遞迴層[1] - /wiki/%E6%B8%85%E6%94%BF%E5%BA%9C (['清政府'])
# 遞迴層[1] - /wiki/%E6%97%A5%E6%9C%AC%E5%9C%8B%E6%9C%83 (['日本國會'])
# 遞迴層[1] - /wiki/%E6%9E%97%E7%86%8A%E5%BE%B5 (['林熊徵'])
# 遞迴層[1] - /wiki/%E6%9E%97%E7%8D%BB%E5%A0%82 (['林獻堂'])
# 遞迴層[1] - /wiki/%E6%9E%97%E7%83%88%E5%A0%82 (['林烈堂'])
# 遞迴層[1] - /wiki/%E6%B8%85%E6%B0%B4%E5%8D%80_(%E5%8F%B0%E7%81%A3) (['清水'])
# 遞迴層[1] - /wiki/%E8%94%A1%E8%93%AE%E8%88%AB (['蔡蓮舫'])
# 遞迴層[1] - /wiki/%E9%B9%BF%E6%B8%AF%E8%BE%9C%E5%AE%B6 (['鹿港辜家'])
# 遞迴層[1] - /wiki/%E8%BE%9C%E9%A1%AF%E6%A6%AE (['辜顯榮'])
# 遞迴層[1] - /wiki/%E5%8F%B0%E4%B8%AD%E4%B8%80%E4%B8%AD (['公立臺中中學校'])
# 遞迴層[1] - /wiki/%E5%8F%B0%E7%81%A3%E7%B8%BD%E7%9D%A3%E5%BA%9C (['台灣總督府'])
# 遞迴層[1] - /wiki/%E8%8F%AF%E5%83%91 (['華僑'])
# 遞迴層[1] - /wiki/%E8%8F%AF%E5%8D%97%E9%8A%80%E8%A1%8C (['華南銀行'])
# 遞迴層[1] - /wiki/%E6%9E%97%E4%BC%AF%E5%A3%BD (['林伯壽'])
# 遞迴層[1] - /wiki/%E4%BA%8C%E6%9E%97%E4%BA%8B%E4%BB%B6 (['二林事件'])
# 遞迴層[1] - /wiki/%E6%B0%B8%E7%90%A6%E7%99%BE%E8%B2%A8 (['永琦百貨'])
# 遞迴層[1] - /wiki/%E8%94%A3%E4%B8%AD%E6%AD%A3%E9%99%B5%E5%AF%A2 (['蔣中正陵寢'])
# 遞迴層[1] - /wiki/%E8%9E%9F%E8%9B%89%E5%AD%90 (['螟蛉子'])
# 遞迴層[1] - /wiki/%E6%8C%89%E5%AF%9F%E4%BD%BF%E9%8A%9C%E5%88%86%E5%B7%A1%E8%87%BA%E7%81%A3%E5%85%B5%E5%82%99%E9%81%93 (['按察使銜分巡臺灣兵備道'])
# 遞迴層[1] - /wiki/%E9%81%93%E5%B0%B9 (['道尹'])
# 遞迴層[1] - /wiki/%E5%8A%89%E7%92%88 (['劉璈'])
# 遞迴層[1] - /wiki/%E4%B8%BE%E4%BA%BA (['舉人'])
# 遞迴層[1] - /wiki/%E6%9E%97%E8%A1%A1%E9%81%93 (['林衡道'])
# 遞迴層[1] - /wiki/%E5%B8%9D%E5%B8%88 (['帝師'])
# 遞迴層[1] - /wiki/%E9%99%B3%E5%AF%B6%E7%90%9B (['陳寶琛'])
# 遞迴層[1] - /wiki/%E6%B2%88%E8%91%86%E6%A5%A8 (['沈葆楨'])
# 遞迴層[1] - /wiki/%E6%9E%97%E5%89%87%E5%BE%90 (['林則徐'])
# 遞迴層[1] - /wiki/%E5%9A%B4%E5%BE%A9 (['嚴復'])
# 遞迴層[1] - /wiki/%E8%BE%9C%E5%9A%B4%E5%80%AC%E9%9B%B2 (['辜嚴倬雲'])
# 遞迴層[1] - /wiki/%E5%9A%B4%E5%83%91 (['嚴僑'])
# 遞迴層[1] - /wiki/%E8%BE%9C%E6%8C%AF%E7%94%AB (['辜振甫'])
# 遞迴層[1] - /wiki/%E5%A7%91%E7%88%B6 (['姑父'])
# 遞迴層[1] - /wiki/%E5%8D%97%E6%B4%8B (['南洋'])
# 遞迴層[1] - /wiki/%E6%AA%B3%E5%9F%8E (['檳城'])
# 遞迴層[1] - /wiki/%E9%A6%AC%E4%BE%86%E8%A5%BF%E4%BA%9E (['馬來西亞'])
# 遞迴層[1] - /wiki/%E8%BE%9C%E7%A6%AE%E6%AD%A1 (['辜禮歡'])
# 遞迴層[1] - /wiki/%E6%9D%9C%E6%B7%91%E7%B4%94 (['杜淑純'])
# 遞迴層[1] - /wiki/%E9%86%AB%E5%AD%B8%E5%8D%9A%E5%A3%AB (['醫學博士'])
# 遞迴層[1] - /wiki/%E6%9D%9C%E8%81%B0%E6%98%8E (['杜聰明'])
# 遞迴層[1] - /wiki/%E9%86%AB%E5%B8%AB (['醫師'])
# 遞迴層[1] - /wiki/%E5%9F%BA%E9%9A%86%E9%A1%8F%E5%AE%B6 (['基隆顏家'])
# 遞迴層[1] - /wiki/%E6%B7%A1%E6%B0%B4 (['淡水'])
# 遞迴層[1] - /wiki/%E8%A8%B1%E4%B8%99 (['許丙'])
# 遞迴層[1] - /wiki/%E6%9E%97%E7%9F%A5%E5%BB%B6 (['林知延'])
# 遞迴層[1] - /wiki/%E6%96%B0%E5%85%89%E9%87%91%E6%8E%A7 (['新光金控'])
# 遞迴層[1] - /wiki/%E5%90%B3%E6%9D%B1%E9%80%B2 (['吳東進'])
# 遞迴層[1] - /wiki/%E5%90%B3%E6%AC%A3%E7%9B%88 (['吳欣盈'])
# 遞迴層[1] - /wiki/%E7%88%B6%E8%A6%AA (['父親'])
# 遞迴層[1] - /wiki/%E8%A8%B1%E5%8D%9A%E5%85%81 (['許博允'])
# 遞迴層[1] - /wiki/%E6%AF%8D%E8%A6%AA (['母親'])
# 遞迴層[1] - /wiki/%E8%87%BA%E7%81%A3%E8%AD%A6%E5%82%99%E7%B8%BD%E5%8F%B8%E4%BB%A4%E9%83%A8 (['臺灣警備總司令'])
# 遞迴層[1] - /wiki/%E9%99%B3%E5%AE%88%E5%B1%B1 (['陳守山'])
# 遞迴層[1] - /wiki/%E4%B8%8A%E5%B0%87 (['上將'])
# 遞迴層[1] - /wiki/%E5%9C%8B%E6%B3%B0 (['國泰'])
# 遞迴層[1] - /wiki/%E5%8F%B0%E5%A1%91 (['台塑'])
# 遞迴層[1] - /wiki/%E6%A3%89%E8%98%AD (['棉蘭'])
# 遞迴層[1] - /wiki/%E5%8D%B0%E5%B0%BC (['印尼'])
# 遞迴層[1] - /wiki/%E8%98%87%E9%96%80%E9%81%94%E8%87%98 (['蘇門達臘'])
# 遞迴層[1] - /wiki/%E9%A6%AC%E5%85%AD%E7%94%B2%E6%B5%B7%E5%B3%BD (['馬六甲海峽'])
# 遞迴層[1] - /wiki/%E5%BC%A0%E9%B8%BF%E5%8D%97 (['張鴻南'])
# 遞迴層[1] - /wiki/%E6%96%B0%E5%8A%A0%E5%9D%A1 (['新加坡'])
# 遞迴層[1] - /wiki/%E9%80%A3%E9%9B%85%E5%A0%82 (['連雅堂'])
# 遞迴層[1] - /wiki/%E9%80%A3%E9%9C%87%E6%9D%B1 (['連震東'])
# 遞迴層[1] - /wiki/%E6%9E%97%E4%BC%AF%E5%A5%8F (['林伯奏'])
# 遞迴層[1] - /wiki/%E6%9E%97%E6%96%87%E6%9C%88 (['林文月'])
# 遞迴層[1] - /wiki/%E8%87%BA%E5%8C%97%E5%B8%82%E9%95%B7 (['臺北市長'])
# 遞迴層[1] - /wiki/%E9%BB%83%E5%A4%A7%E6%B4%B2 (['黃大洲'])
# 遞迴層[1] - /wiki/%E7%AE%A1%E5%AE%B6 (['管家'])
# 遞迴層[1] - /wiki/%E6%9E%97%E7%99%BB%E9%9B%B2 (['林登雲'])
# 遞迴層[1] - /wiki/%E5%A4%A7%E6%BA%AA (['大溪'])
# 遞迴層[1] - /wiki/%E6%96%B0%E5%8C%97%E5%B8%82%E9%95%B7 (['新北市長'])
# 遞迴層[1] - /wiki/%E6%9C%B1%E7%AB%8B%E5%80%AB (['朱立倫'])
# 遞迴層[1] - /wiki/%E5%A4%96%E7%A5%96%E7%88%B6 (['外祖父'])
# 遞迴層[1] - /wiki/%E8%91%A3%E4%BA%8B%E9%95%B7 (['董事長'])
# 遞迴層[1] - /wiki/%E6%9D%8E%E6%89%BF%E5%AE%97 (['李承宗'])
